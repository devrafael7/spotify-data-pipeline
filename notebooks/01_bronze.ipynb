# %%
#CSV1

df = spark.read.option("header", "true").csv("/Workspace/Users/rafael17.oliveira03@gmail.com/spotify-data-pipeline/raw/high_popularity_spotify_data.csv")

df.write.mode("overwrite").saveAsTable(
    "spotify_catalog.bronze.high_popularity_spotify_data_raw"
)

#CSV2

df2 = spark.read.option("header", "true").csv("/Workspace/Users/rafael17.oliveira03@gmail.com/spotify-data-pipeline/raw/low_popularity_spotify_data.csv")

df2.write.mode("overwrite").saveAsTable(
    "spotify_catalog.bronze.low_popularity_spotify_data_raw")

#df_test = spark.table("spotify_catalog.bronze.high_popularity_spotify_data_raw")
#display(df_test)

#df_test2 = spark.table("spotify_catalog.bronze.low_popularity_spotify_data_raw")
#display(df_test2)
